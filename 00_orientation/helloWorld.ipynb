# %% [markdown]
# # 見出し1
# ## 見出し2
# ### 見出し3
# 強調
#
# 太字：**太字** または __太字__
# 斜体：*斜体* または _斜体_
# 訂正線：~~訂正線~~
# 太字かつ斜体：***太字かつ斜体***
#
# - 項目1
# - 項目2
#   - サブ項目
#
# | 見出し1 | 見出し2 |
# | ------- | ------- |
# | データ1 | データ2 |
# | データ3 | データ4 |

# %%
print("Hello! World!")
# Out:
# Hello! World!
