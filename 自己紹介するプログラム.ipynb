# %%
name = input("名前を入力してください：")

# %%
age = input("現在の年齢を入力してください：")

# %%
age = int(age)
age = age + 1

# %%
print(f"名前を入力してください: {name} ")
print(f"現在の年齢を入力してください: {age} ")
print(f"私の名前は {name} です。来年で {age} になります。")
# Out:
# 名前を入力してください: moto
# 現在の年齢を入力してください: 32
# 私の名前は moto です。来年で 32 になります。
